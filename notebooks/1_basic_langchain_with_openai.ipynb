# %% [markdown]
# ##### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ##### Connect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash")

# %%
res = llm.invoke("What is GenAI, explain in short.")

# %%
print(res.content)

# %% [markdown]
# ##### Connect with OpenRouter Model

# %%
from langchain_openrouter import ChatOpenRouter
llm_open = ChatOpenRouter(model="nvidia/nemotron-3.5-lightning:free")

# %%
res = llm_open.invoke("Give me the best startup idea to start in India in fintech or Medtech or Edutech...")

# %%
print(res.content)

# %% [markdown]
# #### Static Prompts

# %%
from langchain_openrouter import ChatOpenRouter
llm_open = ChatOpenRouter(model="nvidia/nemotron-3.5-lightning:free")

# %%
prompts = [
    ("system", "You are a python developer."),      ######(type, ) "system", "ai", 'user'
    ("user", "How to sort the array.")
]
res = llm.invoke(prompts)

# %%
print(res.content)
# Out:
# [{'type': 'text', 'text': 'In Python, how you sort an array depends on whether you are using a **standard Python `list`** or a **NumPy `array`**.\n\nHere are the most common ways to sort them:\n\n---\n\n### 1. Using Standard Python Lists\n\n#### A. In-Place Sorting using `.sort()`\nModifies the original list directly and returns `None`. Best for saving memory.\n\n```python\nnumbers = [5, 2, 9, 1, 5, 6]\nnumbers.sort()\n\nprint(numbers)\n# Output: [1, 2, 5, 5, 6, 9]\n```\n\n#### B. Creating a New Sorted List using `sorted()`\nLeaves the original list unchanged and returns a new sorted list.\n\n```python\nnumbers = [5, 2, 9, 1, 5, 6]\nsorted_numbers = sorted(numbers)\n\nprint(sorted_numbers)  # Output: [1, 2, 5, 5, 6, 9]\nprint(numbers)  # Output: [5, 2, 9, 1, 5, 6] (unchanged)\n```\n\n---\n\n### 2. Sorting in Descending Order (Reverse)\n\nPass `reverse=True` to either `.sort()` or `sorted()`.\n\n```python\nnumbers = [5, 2, 9, 1, 5, 6]\n\n# In-place descending\nnumbers.sort(reverse=Tru
# ...
